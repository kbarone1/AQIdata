# %%
import pandas as pd
import glob
import numpy as np
from matplotlib import pyplot as plt
import datetime

# %%
df = pd.concat([pd.read_csv(f) for f in glob.glob('*.csv')], ignore_index = True)

# %%
df_sf = df[df['CBSA Code']== 41860].reset_index()

# %%
df_sf.head(10)
# Out:
#     index                               CBSA  CBSA Code        Date  AQI  \
# 0  126005  San Francisco-Oakland-Hayward, CA      41860  2004-01-01   54
# 1  126006  San Francisco-Oakland-Hayward, CA      41860  2004-01-02   51
# 2  126007  San Francisco-Oakland-Hayward, CA      41860  2004-01-03   60
# 3  126008  San Francisco-Oakland-Hayward, CA      41860  2004-01-04  107
# 4  126009  San Francisco-Oakland-Hayward, CA      41860  2004-01-05   56
# 5  126010  San Francisco-Oakland-Hayward, CA      41860  2004-01-06   94
# 6  126011  San Francisco-Oakland-Hayward, CA      41860  2004-01-07   95
# 7  126012  San Francisco-Oakland-Hayward, CA      41860  2004-01-08   93
# 8  126013  San Francisco-Oakland-Hayward, CA      41860  2004-01-09   70
# 9  126014  San Francisco-Oakland-Hayward, CA      41860  2004-01-10   65
#
#                          Category Defining Parameter Defining Site  \
# 0                        Moderate              PM2.5   06-081-1001
# 1                        Moderate              PM2.5   06-001-0007
# 2                        Moderate              PM2.5   06-001-0007
# 3  Unhealthy for Sensitive Groups                SO2   06-013-0002
# 4                        Moderate              PM2.5   06-081-1001
# 5                        Moderate              PM2.5   06-001-0007
# 6                        Moderate              PM2.5   06-013-0002
# 7                        Moderate              PM2.5   06-013-0002
# 8                        Moderate              PM2.5   06-001-0007
# 9                        Moderate              PM2.5   06-081-1001
#
#    Number of Sites Reporting
# 0                         15
# 1                         14
# 2                         14
# 3                         15
# 4                         14
# 5                         14
# 6                         15
# 7                         14
# 8                         14
# 9                         15

# %%
print(len(df_sf))
# Out:
# 5723

# %%
df_sf = df[df['CBSA Code']== 41860].reset_index()

# %%
df_sf['Date'] = pd.to_datetime(df_sf['Date'], format = '%Y-%m-%d')

# %%
df_sf['Year'] = pd.DatetimeIndex(df_sf['Date']).year

# %%
df_sf['Month'] = pd.DatetimeIndex(df_sf['Date']).month

# %%
df_sf.head()
# Out:
#     index                               CBSA  CBSA Code       Date  AQI  \
# 0  126005  San Francisco-Oakland-Hayward, CA      41860 2004-01-01   54
# 1  126006  San Francisco-Oakland-Hayward, CA      41860 2004-01-02   51
# 2  126007  San Francisco-Oakland-Hayward, CA      41860 2004-01-03   60
# 3  126008  San Francisco-Oakland-Hayward, CA      41860 2004-01-04  107
# 4  126009  San Francisco-Oakland-Hayward, CA      41860 2004-01-05   56
#
#                          Category Defining Parameter Defining Site  \
# 0                        Moderate              PM2.5   06-081-1001
# 1                        Moderate              PM2.5   06-001-0007
# 2                        Moderate              PM2.5   06-001-0007
# 3  Unhealthy for Sensitive Groups                SO2   06-013-0002
# 4                        Moderate              PM2.5   06-081-1001
#
#    Number of Sites Reporting  Year  Month
# 0                         15  2004      1
# 1                         14  2004      1
# 2                         14  2004      1
# 3                         15  2004      1
# 4                         14  2004      1

# %%
df_sf.head()
# Out:
#     index                               CBSA  CBSA Code       Date  AQI  \
# 0  126005  San Francisco-Oakland-Hayward, CA      41860 2004-01-01   54
# 1  126006  San Francisco-Oakland-Hayward, CA      41860 2004-01-02   51
# 2  126007  San Francisco-Oakland-Hayward, CA      41860 2004-01-03   60
# 3  126008  San Francisco-Oakland-Hayward, CA      41860 2004-01-04  107
# 4  126009  San Francisco-Oakland-Hayward, CA      41860 2004-01-05   56
#
#                          Category Defining Parameter Defining Site  \
# 0                        Moderate              PM2.5   06-081-1001
# 1                        Moderate              PM2.5   06-001-0007
# 2                        Moderate              PM2.5   06-001-0007
# 3  Unhealthy for Sensitive Groups                SO2   06-013-0002
# 4                        Moderate              PM2.5   06-081-1001
#
#    Number of Sites Reporting  Year  Month
# 0                         15  2004      1
# 1                         14  2004      1
# 2                         14  2004      1
# 3                         15  2004      1
# 4                         14  2004      1

# %%
df_sf_month = df_sf.groupby(['Year','Month']).AQI.mean().reset_index()

# %%
plt.scatter()
# Out:
#      Year  Month         AQI
# 0    2004      1   76.322581
# 1    2004      2   49.620690
# 2    2004      3   53.258065
# 3    2004      4   54.833333
# 4    2004      5   46.903226
# 5    2004      6   47.433333
# 6    2004      7   46.129032
# 7    2004      8   52.741935
# 8    2004      9   62.433333
# 9    2004     10   48.612903
# 10   2004     11   67.766667
# 11   2004     12   75.387097
# 12   2005      1   71.645161
# 13   2005      2   51.857143
# 14   2005      3   46.548387
# 15   2005      4   42.266667
# 16   2005      5   42.129032
# 17   2005      6   41.800000
# 18   2005      7   64.064516
# 19   2005      8   59.516129
# 20   2005      9   57.033333
# 21   2005     10   48.096774
# 22   2005     11   61.333333
# 23   2005     12   72.741935
# 24   2006      1   50.580645
# 25   2006      2   59.214286
# 26   2006      3   41.064516
# 27   2006      4   43.333333
# 28   2006      5   53.032258
# 29   2006      6   60.766667
# ..    ...    ...         ...
# 159  2017      4   46.333333
# 160  2017      5   49.322581
# 161  2017      6   50.833333
# 162  2017      7   52.161290
# 163  2017      8   65.677419
# 164  2017      9   70.433333
# 165  2017     10   77.516129
# 166  2017     11   52.200000
# 167  2017     12   72.935484
# 168  2018      1   65.354839
# 169  2018      2   53.571429
# 170  2018      3   48.193548
# 171  2018      4   51.200000
# 172  2018      5   46.935484
# 173  2018      6   59.366667
# 174  2018      7   54.193548
# 175  2018      8   68.451613
# 176  2018      9   57.433333
# 177  2018     10   51.290323
# 178  2018     11  104.033333
# 179  2018     12   48.612903
# 180  2019      1   54.612903
# 181  2019      2   37.964286
# 182  2019      3   42.322581
# 183  2019      4   48.200000
# 184  2019      5   43.290323
# 185  2019      6   55.300000
# 186  2019      7   50.000000
# 187  2019      8   51.354839
# 188  2019      9    7.000000
#
# [189 rows x 3 columns]

# %%
df_sf.head()
# Out:
#     index                               CBSA  CBSA Code       Date  AQI  \
# 0  126005  San Francisco-Oakland-Hayward, CA      41860 2004-01-01   54
# 1  126006  San Francisco-Oakland-Hayward, CA      41860 2004-01-02   51
# 2  126007  San Francisco-Oakland-Hayward, CA      41860 2004-01-03   60
# 3  126008  San Francisco-Oakland-Hayward, CA      41860 2004-01-04  107
# 4  126009  San Francisco-Oakland-Hayward, CA      41860 2004-01-05   56
#
#                          Category Defining Parameter Defining Site  \
# 0                        Moderate              PM2.5   06-081-1001
# 1                        Moderate              PM2.5   06-001-0007
# 2                        Moderate              PM2.5   06-001-0007
# 3  Unhealthy for Sensitive Groups                SO2   06-013-0002
# 4                        Moderate              PM2.5   06-081-1001
#
#    Number of Sites Reporting  Year  Month
# 0                         15  2004      1
# 1                         14  2004      1
# 2                         14  2004      1
# 3                         15  2004      1
# 4                         14  2004      1

# %%
print(df_sf.dtypes)
# Out:
# index                                 int64
# CBSA                                 object
# CBSA Code                             int64
# Date                         datetime64[ns]
# AQI                                   int64
# Category                             object
# Defining Parameter                   object
# Defining Site                        object
# Number of Sites Reporting             int64
# Year                                  int64
# Month                                 int64
# dtype: object

# %%
plt.scatter(df_sf['Date'], df_sf['AQI'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2c074cb8b89a> in <module>()
# ----> 1 plt.scatter(df_sf['Date'], df_sf['AQI'])
#       2 plt.show()
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3376                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3377                          linewidths=linewidths, verts=verts,
# -> 3378                          edgecolors=edgecolors, data=data, **kwargs)
#    3379     finally:
#    3380         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4021             linewidths = rcParams['lines.linewidth']
#    4022
# -> 4023         offsets = np.column_stack([x, y])
#    4024
#    4025         collection = mcoll.PathCollection(
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/shape_base.py in column_stack(tup)
#     367             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     368         arrays.append(arr)
# --> 369     return _nx.concatenate(arrays, 1)
#     370
#     371 def dstack(tup):
#
# TypeError: invalid type promotion

# %%
ls
